# %% [markdown]
# <a href="https://colab.research.google.com/github/SanchitaMahajan/ISYS5002_Portfolio/blob/main/Copy_of_amazon_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kora -q
'''load packages'''
from bs4 import BeautifulSoup
from kora.selenium import wd

# %%
# Establish Session
url = 'https://www.amazon.com.au'
wd.get(url)

# %%
# work out the URL Pattern
template = 'https://www.amazon.com.au/s?k={}&ref=nb_sb_noss_2'

#search_term = input("What do you want to search for?")
search_term = 'ultrawide monitor'

# replace spaces with a '+' sign
search_term = search_term.replace(' ', '+')

url = template.format(search_term)
wd.get(url)

# %%
def get_url(search_term):
  template = 'https://www.amazon.com.au/s?k={}&ref=nb_sb_noss_2'
  # replace spaces with a '+' sign
  search_term = search_term.replace(' ', '+')
  url = template.format(search_term)

  return url

# %%
# search_term = input("What do you want to search for? ")

search_term = 'ultrawide monitor'
url = get_url(search_term)
wd.get(url)

# %%
soup = BeautifulSoup(wd.page_source, 'html.parser')
soup
# Out:
# <html class=" a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition a-ember" data-19ax5a9jf="dingo" data-aui-build-date="3.21.7-2021-10-06" lang="en-au"><!-- sp:feature:head-start --><head><script async="" crossorigin="anonymous" src="https://c.amazon-adsystem.com/bao-csm/forensics/a9-tq-forensics-incremental.min.js"></script><script async="" crossorigin="anonymous" src="https://images-fe.ssl-images-amazon.com/images/I/31YXrY93hfL.js"></script><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# ...

# %% [markdown]
# # Extract the Collection

# %%
soup = BeautifulSoup(wd.page_source, 'html.parser')
soup
results = soup.find_all('div', { 'data-component-type': 's-search-result'})
results[0]
# Out:
# <div class="sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col sg-col-4-of-20" data-asin="B01BV1XB2K" data-cel-widget="search_result_1" data-component-id="5" data-component-type="s-search-result" data-index="7" data-uuid="0af2798d-d0b5-49e4-9d7a-e7d8a346a8ea"><div class="sg-col-inner">
# <span cel_widget_id="MAIN-SEARCH_RESULTS-7" class="celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results_1" data-cel-widget="MAIN-SEARCH_RESULTS-7" data-csa-c-id="q8mygc-hut3i5-bv8nfd-shvorb">
# ...

# %%
results[0].h2.a.text
# Out:
# 'LG 25UM58-P 25-Inch 21:9 UltraWide IPS Monitor with Screen Split '

# %%
def extract_description(item):
  description = item.h2.a.text
  return description

# %%
extract_description(results[11])
# Out:
# 'AVLT Single 13"-38" Monitor Arm Desk Mount fits One Flat/Curved/Ultrawide Monitor Full Motion Height Swivel Tilt Rotation Adjustable Monitor Arm - VESA/C-Clamp/Cable Management '

# %% [markdown]
# # Prototype the record

# %%
item = results[0]
price_parent = item.find('span', 'a-price')
price = price_parent.find('span','a-offscreen')
price.text
# Out:
# '$279.00'

# %%
def extract_price(item):
  try:
    price_parent = item.find('span', 'a-price')
    price = price_parent.find('span', 'a-offscreen')
    price = price.text
  except AttributeError:
    price = ''  
    return price

# %%
extract_price(results[1])

# %%
def extract_record(item):
  return {
      'description': extract_description(item),
      'price': extract_price(item)
  }

# %%
extract_record(results[0])
# Out:
# {'description': 'LG 25UM58-P 25-Inch 21:9 UltraWide IPS Monitor with Screen Split ',
#  'price': None}

# %%
for r in results:
  print(extract_record(r))
# Out:
# {'description': 'LG 25UM58-P 25-Inch 21:9 UltraWide IPS Monitor with Screen Split ', 'price': None}
# {'description': 'LG 34BN670-B 34” IPS FHD UltraWide Monitor (2560x1080) with 21:9 Aspect Ratio, VESA DisplayHDR 400, AMD FreeSync, Black ', 'price': None}
# {'description': 'VIVO Heavy Duty Single 17 to 35 inch Monitor Pneumatic Spring Arm Stand, Aluminum Clamp-on Desk Mount, Fits 1 Screen, Max VESA 100x100, Black, STAND-V100G ', 'price': None}
# {'description': 'BenQ 32" Designer Monitor, 3840x2160 4K UHD, IPS, 100% sRGB, Hotkey Puck, Dual View, HDMI, DP, PD3200U ', 'price': None}
# {'description': 'BenQ 32 inch 144 Hz Curved Gaming Monitor ( EX3203R ), 2K QHD, FreeSync 2, Display HDR 400, B.I. Plus Sensor, USB-C ', 'price': None}
# {'description': 'BenQ EW3270U 32 inch 4K HDR Video Enjoyment Monitor FreeSync USB-C connectivity ', 'price': ''}
# ...

# %%
records = []
for r in results:
  records.append(extract_record(r))

records[0]
# Out:
# {'description': 'LG 25UM58-P 25-Inch 21:9 UltraWide IPS Monitor with Screen Split ',
#  'price': None}

# %%
import pandas as pd

df = pd.DataFrame.from_records(records)
df.head
# Out:
# <bound method NDFrame.head of                                           description price
# 0   LG 25UM58-P 25-Inch 21:9 UltraWide IPS Monitor...  None
# 1   LG 34BN670-B 34” IPS FHD UltraWide Monitor (25...  None
# 2   VIVO Heavy Duty Single 17 to 35 inch Monitor P...  None
# 3   BenQ 32" Designer Monitor, 3840x2160 4K UHD, I...  None
# 4   BenQ 32 inch 144 Hz Curved Gaming Monitor ( EX...  None
# 5   BenQ EW3270U 32 inch 4K HDR Video Enjoyment Mo...
# 6   BenQ 27" IPS Designer Monitor, 2560x1440 QHD 2...
# 7   Dell S3221QS 32 Inch Curved 4K UHD Monitor, VA...  None
# 8   BenQ 27 Inch 1080p LED IPS Eye Care Monitor (G...
# 9   VIVO Single LCD Monitor Desk Mount Stand Fully...  None
# 10   ERGOTRON 45-475-216 HX Desk Monitor Arm (White)   None
# 11  AVLT Single 13"-38" Monitor Arm Desk Mount fit...  None
# 12  VIVO 17 to 43 inch Aluminum Single Ultrawide M...  None
# 13  Single LCD Monitor Desk Mount Fully Adjustable...  None
# ...

# %% [markdown]
# # Generalize the pattern

# %%
records = []
results = soup.find_all('div', {'data-component-type': 's-search-result'})

for item in results:
  records.append(extract_record(item))

# %% [markdown]
# # Error Handling

# %% [markdown]
# # Find next page

# %% [markdown]
# # Putting it all together

# %%
# !pip install kora -q

'''load packages'''
from bs4 import BeautifulSoup
from kora.selenium import wd
import pandas as pd






def get_url(search_term):
  template = 'https://www.amazon.com.au/s?k={}&ref=nb_sb_noss_2'
  # replace spaces with a '+' sign
  search_term = search_term.replace(' ', '+')
  url = template.format(search_term)

  return url

def extract_description(item):
  description = item.h2.a.text
  return description

def extract_price(item):
  try:
    price_parent = item.find('span', 'a-price')
    price = price_parent.find('span', 'a-offscreen')
    price = price.text
  except AttributeError:
    price = ''  
    return price

  def extract_record(item):
   return {
      'description': extract_description(item),
      'price': extract_price(item)
   }

# %%
# Establish Session
url = 'https://www.amazon.com.au'
wd.get(url)


search_term = input("What do you want to search for? ")
url = get_url(search_term)
wd.get(url) 
soup = BeautifulSoup(wd.page_source, 'html.parser')
records = []
results = soup.find_all('div', {'data-component-type': 's-search-result'})

for item in results:
   records.append(extract_record(item))

#wd.close()
df = pd.DataFrame.from_records(records)
df.head()
# Out:
# What do you want to search for? mouse pad
#                                          description price
# 0  Corsair CH-9100020-WW MM100 Performance Gaming...
# 1                  Fellowes Mouse Pad, Black, 27317
# 2  Corsair CH-9000108-WW MM300- Anti-Fray Cloth G...
# 3  SteelSeries QcK Gaming Surface - Medium Stitch...
# 4  Corsair MM350 PRO Premium Spill-Proof, Stain-R...

# %%
df = amazon_as_dataframe("ultrawide monitor")
